# %% [markdown]
# # Data Science Visualization - Matplotlib

# %% [markdown]
# ## Tasks Today:
#
# 1) <b>Matplotlib</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Data Visulation <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Importing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Different Types of Charts <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Basics <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Customization <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Axis Labels & Line Marks <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Legend & Line Labels <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Subplots <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) <b>In-Class Exercise #1</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Presentation Worthiness <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) <b>In-Class Exercise #2</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Box Plot <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; j) Scatter Plot <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; k) Histograms <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; l) 3-D Plotting <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; m) Flattening Multidimensional Data <br>

# %% [markdown]
# ### Data Visualization <br>
# <p>Data visualization is one of the most powerful tools an analyst has for two main reasons. Firstly, it is unrivalled in it's ability to guide the analysts hand in determining 'what to look at next'. Often a visual is revealing of patterns in the data that are not easily discernable by just looking at dataframes. Secondly, they are an analysts greatest communication tool. Very often professional analysts need to present their results to groups of people responsible for taking action based on what the data says. Visuals can tell your story much better then raw numbers, so let's talk a little bit about how to make effective visuals that make a point.</p>

# %% [markdown]
# ##### Importing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # standard

# %% [markdown]
# ### Different Types of Charts <br>
# <ul>
#     <li><b>Line Chart:</b> Exploring data over time</li>
#     <li><b>Bar Chart:</b> Comparing categories of data and tracks changes over time</li>
#     <li><b>Pie Chart:</b> Explore parts of a whole, i.e. fractions</li>
#     <li><b>Scatter Plot:</b> Similar to line charts, track correlations between two categories</li>
#     <li><b>Histogram:</b> Unrelated from bar charts, show distribution of variables</li>
#     <li><b>Candlestick Chart:</b> Used a lot in financial sector, i.e. can compare a stock over a period of time</li>
#     <li><b>Box Chart:</b> Looks identical to candlestick charts, compares minimum, 1st, medium, 3rd quartiles, and max values</li>
# </ul>
#
# <p>Depending on what you need to accomplish in conceptualizing your data, you will go with a specific type of chart to portray your data.</p>

# %% [markdown]
# ### Basics <br>
# <p>Plots can be as detailed as you'd like them to be, but the simplest plot to start with can be done in just a few lines:</p>

# %%
plt.plot([1,2,3,4,5])
plt.show()

# %% [markdown]
# ### Customization <br>
# <p>There's many customizable options when using Matplotlib, such as; line types, colors, labels, figure size, etc. We'll go over a few of them here:</p>

# %% [markdown]
# ##### Axis Labels & Line Marks

# %%
plt.plot([1,2,3,4,5], [23, 45, 67, 78, 89], 'bo-')
plt.plot([2,3,4,5], [2, 33, 90, 105], 'rx:')
plt.xlabel('x value')
plt.ylabel('y value')
plt.show()

# %% [markdown]
# ##### Legend & Line Labels

# %%
plt.plot([1600, 1700, 1800, 1900, 2000], [1, 1.4, 1.6, 1.8, 2.0], 'yo-.', label='First')
plt.plot([1600, 1700, 1800, 1900, 2000], [2, 1.5, 1.6, 1.8, 1.5], 'gx:', label='Second')
plt.xlabel('x value')
plt.ylabel('y value')
plt.legend()
plt.show()

# %% [markdown]
# ### Subplots <br>
# <p>Using the subplots method, you're able to create multiple plots within a single cell.</p>

# %%
plot_1 = plt.subplot(2,1,1)
plot_1.plot([1600, 1700, 1800, 1900, 2000], [1, 1.4, 1.6, 1.8, 2.0], 'yo-.', label='First')
plot_1.set_xlim([1550, 2050])
plot_1.set_ylim([0, 3])
plt.xlabel('x value')
plt.ylabel('y value')
plt.legend()

plot_2 = plt.subplot(2,1,2) 
plot_2.plot([1600, 1700, 1800, 1900, 2000], [2, 1.5, 1.6, 1.8, 1.5], 'gx:', label='Second')
plot_2.set_xlim([1550, 2050])
plot_2.set_ylim([0, 3])
plt.xlabel('x value')
plt.ylabel('y value')
plt.legend()

plt.show()

# %% [markdown]
# ### In-Class Exercise #1 - Create a Graph that Depicts y = f(x)

# %%
import math
y = []
x = []
for item in np.arange(0, 10, 0.1): 
    x.append(item)
    y.append(math.sin(item))

plt.plot(x, y, 'ro:', label='sin(x)') 
plt.xlabel('x value')
plt.ylabel('y value')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
x = np.linspace(0, 10, 20)
y = x ** 2

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Presentation Worthiness
# <p>Before we go into how to use this as a tool for data exploration, let's talk quickly about presentation-worthiness. In the next cell we're going to introduce customization of lines, colors, ticks, titles, fonts, and grids.</p>

# %%
fig, ax = plt.subplots(figsize=(20, 10))
plt.plot(x, y,
        lw = 5,
        ls = '--',
        color = 'r',
        marker = '*',
        markersize = 15,
        markerfacecolor = 'b',
        label = 'Data')
plt.xlabel(r'$x$ value', fontname = 'Times New Roman', fontsize = 32)
plt.ylabel(r'$y$ value', fontname = 'Times New Roman', fontsize = 32)
plt.xticks(fontsize = 28)
plt.yticks(fontsize = 28)
plt.title(r'$y = f(x) = x^2$', fontname = 'Times New Roman', fontsize = 40, y = 1.05)
plt.grid(True)
plt.legend(loc='upper left', fontsize = 40)
plt.tight_layout()
plt.savefig('data.png')

# %% [markdown]
# <p>It's sometimes nice to obsess a little bit over how your plots look. It's good practice paying attention to detail and it has huge payoff when you end up presenting your findings to other analysts and business parteners. Here's a more complex example of using the matplotlib api:</p>

# %%
markers = ['o', 'v', '^', '*', 's']
styles = ['-', '--', '-.', ':', '-']
colors = ['#588C7E', '#F2E394', '#F2AE72', '#D96459', '#8C4646']

# %%
x = np.linspace(0, 10, 50)
fig, ax = plt.subplots(figsize = (20, 10))
for i in range(5):
    plt.plot(x, x ** i,
            lw = 5,
            ls = styles[i],
            color = colors[i],
            marker = markers[i],
            markersize = 15,
            markerfacecolor = colors[i],
            label = r'$x^{%s}$' % i)
plt.xlim(0, 10, 50)
plt.ylim(0, 100)
plt.xlabel(r'$x$ value', fontname = 'Times New Roman', fontsize = 32)
plt.ylabel(r'$y$ value', fontname = 'Times New Roman', fontsize = 32)
plt.xticks(fontsize = 28)
plt.yticks(fontsize = 28)
plt.title(r'$y = f(x) = x^2$', fontname = 'Times New Roman', fontsize = 40, y = 1.05)
plt.grid(True)
plt.legend(loc='upper left', fontsize = 40)
plt.tight_layout()
plt.savefig('data2.png')

# %% [markdown]
# ### In-Class Exercise #2 - Customize the f(x) Plot Created Earlier <br>
# <p>Customize it however you would like...</p>

# %%
x = np.linspace(1, 10)
sinx = []
cosx = []
for item in x:
    sinx.append(math.sin(item))
    cosx.append(math.cos(item))

fig = plt.figure(figsize = (20, 10))
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
ax1.plot(x, sinx, 'ro:', label=r'$sin(x)$') 
# ax1.set_xlabel(r'$x$', fontname = 'Times New Roman', fontsize = 32)
ax1.set_ylabel(r'$sin(x)$', fontname = 'Times New Roman', fontsize = 32)
ax1.set_title(r'$sin(x)$', fontname = 'Times New Roman', fontsize = 40, y = 1.05)
ax1.grid(True)
ax1.legend(loc='best', fontsize = 20)
# ax1.tight_layout()
ax2.plot(x, cosx, 'bo:', label=r'$cos(x)$') 
ax2.set_xlabel(r'$x$', fontname = 'Times New Roman', fontsize = 32)
ax2.set_ylabel(r'$cos(x)$', fontname = 'Times New Roman', fontsize = 32)
ax2.set_title(r'$cos(x)$', fontname = 'Times New Roman', fontsize = 40, y = 1.05)
ax2.grid(True)
ax2.legend(loc='best', fontsize = 20)
# plt.title(r'$sin(x) and cos(x)$', fontname = 'Times New Roman', fontsize = 32)
fig.savefig('data3.png')

# %%
# worth noting how to use groupby

from itertools import groupby #import

# define a list
things = [("animal", "bear"), ("animal", "duck"), ("plant", "cactus"), ("vehicle", "speed boat"), ("vehicle", "school bus")]

# pull key, and values from list
for key, group in groupby(things, lambda x: x[0]):
    # each group are those tuples, each key is the index we specify in the lambda, which is the type
    for thing in group:
        print(thing)
        print('A %s is a %s.' % (thing[1], key))
    print(" ")
# Out:
# ('animal', 'bear')
# A bear is a animal.
# ('animal', 'duck')
# A duck is a animal.
#
# ('plant', 'cactus')
# A cactus is a plant.
#
# ('vehicle', 'speed boat')
# A speed boat is a vehicle.
# ('vehicle', 'school bus')
# A school bus is a vehicle.

# %% [markdown]
# ### Scatter Plot

# %%
import csv

data_file = 'iris.csv'

plt.figure(figsize = (10, 7))

def read_csv(filename):
    with open(filename, 'r') as f:
        data = list(csv.reader(f))
    return data

flowers = read_csv(data_file)

colors = {
    'Iris-setosa' : '#285884',
    'Iris-versicolor' : 'g',
    'Iris-virginica' : 'purple'
}

flowers.pop()

for species, group in groupby(flowers, lambda x: x[4]):
    flower_cat = list(group)
    sepal_length = [float(flower[0]) for flower in flower_cat]
    sepal_width = [float(flower[1]) for flower in flower_cat]
    plt.scatter(sepal_length, sepal_width, s = 10, c = colors[species], label = species)

plt.title('Iris data', fontname = 'Times New Roman', fontsize = 20)
plt.xlabel('Sepal length [cm]', fontname = 'Times New Roman', fontsize = 20)
plt.ylabel('Sepal width [cm]', fontname = 'Times New Roman', fontsize = 20)
plt.legend(loc = 'best') #.get_frame().set_color('chocolate')

# %% [markdown]
# ### Box Plot

# %%
data_file = 'iris.csv'
# plt.figure(figsize=(10, 7))

fig = plt.figure(figsize=(10, 7))

def read_csv(filename):
    with open(filename, 'r') as f:
        data = list(csv.reader(f))
    return data

flowers = read_csv(data_file)
flowers.pop()

petal_length = []

for species, group in groupby(flowers, lambda x: x[4]):
    petal_length.append([float(petal[2]) for petal in group])
    
plt.boxplot(petal_length)
plt.axis([0,4,0,10])
plt.xticks([1,2,3], ['Setosa','Versicolor', 'Virginica'], fontname = 'Times New Roman', fontsize = 20)
plt.title('Iris Data', fontname = 'Times New Roman', fontsize = 20)
plt.xlabel('Iris', fontname = 'Times New Roman', fontsize = 20)
plt.ylabel('Petal length [m]', fontname = 'Times New Roman', fontsize = 20)
plt.show()

# %% [markdown]
# ### Histograms <br>
# <p>While line plots are great for visualizing trends in time series data, histograms are the king of visualizing distributions. Often, the distribution of a variable is what you're interested in, and a visualization provides a lot more information than a group of summary statistics.</p>

# %%
fig, ax = plt.subplots(figsize=(10, 7))

data = np.random.uniform(0, 100, 10000)

plt.hist(data, bins = 50, normed = 1, label = 'Data', color = 'r', alpha = 0.75)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlabel('Value', fontsize = 20)
plt.ylabel('Frequency', fontsize = 20)
plt.title('Histogram', fontsize = 30)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <p>Let's take a look at a mystery/randomly generated DataFrame, and plot the results</p>

# %%
import pandas as pd
import numpy as np
def make_mystery_dataframe():
    customer_id = np.random.randint(100000,120000,10000)
    
    
    states = {1:'California', 0:'New York'}
    statelist = []
    agelist = []
    for i in range(10000):
        ind = np.random.randint(0, 2)
        if ind == 0:
            statelist.append(states[ind])
            agelist.append(np.random.normal(loc=30, scale=10))
        elif ind == 1:
            statelist.append(states[ind])
            agelist.append(np.random.normal(loc=40, scale=20))
    
    mystery_df = pd.DataFrame.from_dict({'customer_id': customer_id,
                                         'ages':agelist,
                                         'state':statelist})
    
    return mystery_df
            

mystery_df = make_mystery_dataframe()
mystery_df.head()
# Out:
#    customer_id       ages       state
# 0       101143  50.450549  California
# 1       118353  25.761411  California
# 2       103294  19.969753    New York
# 3       115421  36.527257    New York
# 4       103990  36.434607    New York

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20, 10))

ax1.hist(mystery_df[mystery_df['state'] == 'California']['ages'], bins = 50, label = 'California', color = 'r')
ax1.set_xlabel('Age', fontname = 'Times New Roman', fontsize = 30)
ax1.set_ylabel('Frequency', fontname = 'Times New Roman', fontsize = 30)
ax1.legend(loc = 'best', fontsize=20)

ax2.hist(mystery_df[mystery_df['state'] == 'New York']['ages'], bins = 50, label = 'New York')
ax2.set_xlabel('Age', fontname = 'Times New Roman', fontsize = 30)
ax2.set_ylabel('Frequency', fontname = 'Times New Roman', fontsize = 30)
ax2.legend(loc = 'best', fontsize=20)

# %%
plt.subplots(figsize = (20, 10))

plt.hist(mystery_df[mystery_df['state'] == 'California']['ages'], bins = 50, label = 'California', color = 'r', alpha = 0.5)
plt.hist(mystery_df[mystery_df['state'] == 'New York']['ages'], bins = 50, label = 'New York', color = 'b', alpha = 0.5)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)
plt.xlabel('Age', fontsize = 30)
plt.ylabel('Frequency', fontsize = 30)
plt.legend(loc = 'best', fontsize = 30)
plt.title('Age Histogram', fontsize = 30)
# Out:
# Text(0.5,1,'Age Histogram')

# %% [markdown]
# ### 3-D Plotting <br>
# <p>Without going into too much detail, here's a quick example of the type of 3-D plotting that's possible with matplotlib (example stolen from the official docs):</p>

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.tri as mtri

fig = plt.figure(figsize=(20,10))

#============
# First plot
#============

# Make a mesh in the space of parameterisation variables u and v
u = np.linspace(0, 2.0 * np.pi, endpoint=True, num=50)
v = np.linspace(-0.5, 0.5, endpoint=True, num=10)
u, v = np.meshgrid(u, v)
u, v = u.flatten(), v.flatten()

# This is the Mobius mapping, taking a u, v pair and returning an x, y, z
# triple
x = (1 + 0.5 * v * np.cos(u / 2.0)) * np.cos(u)
y = (1 + 0.5 * v * np.cos(u / 2.0)) * np.sin(u)
z = 0.5 * v * np.sin(u / 2.0)

# Triangulate parameter space to determine the triangles
tri = mtri.Triangulation(u, v)

# Plot the surface.  The triangles in parameter space determine which x, y, z
# points are connected by an edge.
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap=plt.cm.Spectral)
ax.set_zlim(-1, 1)


#============
# Second plot
#============

# Make parameter spaces radii and angles.
n_angles = 36
n_radii = 8
min_radius = 0.25
radii = np.linspace(min_radius, 0.95, n_radii)

angles = np.linspace(0, 2*np.pi, n_angles, endpoint=False)
angles = np.repeat(angles[..., np.newaxis], n_radii, axis=1)
angles[:, 1::2] += np.pi/n_angles

# Map radius, angle pairs to x, y, z points.
x = (radii*np.cos(angles)).flatten()
y = (radii*np.sin(angles)).flatten()
z = (np.cos(radii)*np.cos(angles*3.0)).flatten()

# Create the Triangulation; no triangles so Delaunay triangulation created.
triang = mtri.Triangulation(x, y)

# Mask off unwanted triangles.
xmid = x[triang.triangles].mean(axis=1)
ymid = y[triang.triangles].mean(axis=1)
mask = np.where(xmid**2 + ymid**2 < min_radius**2, 1, 0)
triang.set_mask(mask)

# Plot the surface.
ax = fig.add_subplot(1, 2, 2, projection='3d')
ax.plot_trisurf(triang, z, cmap=plt.cm.CMRmap)


plt.show()

# %% [markdown]
# ### Flattening Multidimensional Data

# %% [markdown]
# <p>Generally in data science you want to avoid 3D plotting wherever possible - not because the information you want to convey is not contained within the result, sometimes it is simply because your point is easier to express by denoting one of the axes using color or some other means. For instance, imagine you are asked to investigate the effects of driver age and car engine size on number of traffic violiations. That is, you are attempting to describe a function - the number of traffic violations - of two variables, age and engine size. You could make a 3D scatterplot, but let's see if we can come up with something better:</p>

# %%
from scipy.stats import norm

def random_line(m, b, sigma, size=150):
    '''create some fake data about drivers!'''
    
    
    xdata = np.linspace(18,100,size)
    # Generate normally distributed random error ~ N(0, sigma**2)
    #errors = norm.rvs(loc=0, scale=sigma, size=size)
    errors = np.random.uniform(20,100,size) + np.random.uniform(20,100,size) + np.random.uniform(20,100,size)
    ydata = (m * xdata + b + errors) / 20
    
    num_accidents = (np.round(np.random.uniform(0,1,size) + (10-xdata)+ydata) / 10 + 10) + (ydata/5)
    return xdata, ydata-7, num_accidents

# %%
ages, engine_sizes, num_accidents = random_line(1.35, 2, 3)

# %%
fig, ax = plt.subplots(figsize = (12, 7))

plt.scatter(ages, engine_sizes, c = num_accidents)
plt.xlabel('Age', fontsize = 20)
plt.ylabel('Engine', fontsize = 20)
plt.colorbar(cmap = 'rainbow', label = 'Viollations')
